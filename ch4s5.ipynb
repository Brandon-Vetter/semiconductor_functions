# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import *
import scipy as si


Nd = 1E16
Na = 1E15


    

x = np.arange(-10E-5,10E-5+1E-7, 1E-7)


V = find_bias_V_pn(Na, Nd, x)
plt.plot(x, V)
# Out:
# 9.688707060677507e-05
# 9.204271707643633e-05
# -4.844353530338754e-06
# 9.688707060677507e-05

# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import *
import scipy as si

x = np.arange(-2E-5,2E-5+1E-7, 1E-7)

bias = surf_pot(Na, Nd)
print(bias)
# Out:
# 0.8509216147030805
